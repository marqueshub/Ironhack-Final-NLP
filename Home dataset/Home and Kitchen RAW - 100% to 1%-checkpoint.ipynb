# %%
#Home and kitchen - Amazon 2018

# %% [markdown]
# https://nijianmo.github.io/amazon/index.html

# %%
import os
import json
import gzip
import pandas as pd
from urllib.request import urlopen

# %%
#to check the path

# !pwd
# Out:
# /Users/juliamarques/Documents/GitHub/Ironhack_Final_Project/Home dataset

# %%
#Home and kitchen reviews from 5-core

home_df = pd.read_json('Home_and_Kitchen_5.json',lines=True)

# %%
home_df
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 0              5      True   11 5, 2015   A8LUWTIPU9CZB  0560467893
# 1              3      True   05 7, 2015  A3B6GKQQ1JJ167  0560467893
# 2              5      True  01 22, 2014  A3MCTN65BU7XRA  0681795107
# 3              1      True  10 30, 2013   A7JVZFSXVY9RL  0681795107
# 4              1      True  09 20, 2013  A2RQ7VLAK1SHPU  0681795107
# ...          ...       ...          ...             ...         ...
# 6898950        5      True   08 8, 2016   AB4CZUDHN52H5  B01HJEJDBQ
# 6898951        2      True   09 5, 2017  A12NA9GEGY6I3E  B01HJEOT2E
# 6898952        4      True  07 30, 2017  A38PQCNDGGWSPQ  B01HJEOT2E
# 6898953        4      True  07 28, 2018  A2AY2C5EW8VOO7  B01HJGJNWS
# 6898954        5      True  07 22, 2018   A53HGFV9H8A5F  B01HJGJNWS
#
#             reviewerName                                         reviewText  \
# ...

# %%
#Dropping the unnecessary columns

home_df = home_df.drop(columns=['vote', 'style', 'image', 'reviewTime', 'reviewerID', 'reviewerName', 'unixReviewTime' ], axis = 1)

# %%
home_df
# Out:
#          overall  verified        asin  \
# 0              5      True  0560467893
# 1              3      True  0560467893
# 2              5      True  0681795107
# 3              1      True  0681795107
# 4              1      True  0681795107
# ...          ...       ...         ...
# 6898950        5      True  B01HJEJDBQ
# 6898951        2      True  B01HJEOT2E
# 6898952        4      True  B01HJEOT2E
# 6898953        4      True  B01HJGJNWS
# 6898954        5      True  B01HJGJNWS
#
#                                                 reviewText  \
# 0                                 Great product, love it!!
# 1        Pretty flimsy, but does the job. If your corne...
# 2        So much better than plastic mug types--keeps c...
# 3        I like my coffee hot; borderline scorching but...
# 4        This mug does only a fair job of keeping coffe...
# ...                                                    ...
# 6898950  I purchased these as decorations for my classr...
# ...

# %%
#checking for null values 

home_df.isna().any()
# Out:
# overall       False
# verified      False
# asin          False
# reviewText     True
# summary        True
# dtype: bool

# %%
#count of nule values per column

home_df.isna().sum()
# Out:
# overall          0
# verified         0
# asin             0
# reviewText    2581
# summary       1301
# dtype: int64

# %%
#dropping nule values

home_df.dropna(inplace = True, axis = 0)

# %%
#old: 6.898.955 rows 
#new: 6.895.163 rows  

home_df
# Out:
#          overall  verified        asin  \
# 0              5      True  0560467893
# 1              3      True  0560467893
# 2              5      True  0681795107
# 3              1      True  0681795107
# 4              1      True  0681795107
# ...          ...       ...         ...
# 6898950        5      True  B01HJEJDBQ
# 6898951        2      True  B01HJEOT2E
# 6898952        4      True  B01HJEOT2E
# 6898953        4      True  B01HJGJNWS
# 6898954        5      True  B01HJGJNWS
#
#                                                 reviewText  \
# 0                                 Great product, love it!!
# 1        Pretty flimsy, but does the job. If your corne...
# 2        So much better than plastic mug types--keeps c...
# 3        I like my coffee hot; borderline scorching but...
# 4        This mug does only a fair job of keeping coffe...
# ...                                                    ...
# 6898950  I purchased these as decorations for my classr...
# ...

# %%
home_df.info() #data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6895163 entries, 0 to 6898954
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   overall     int64
#  1   verified    bool
#  2   asin        object
#  3   reviewText  object
#  4   summary     object
# dtypes: bool(1), int64(1), object(3)
# memory usage: 269.6+ MB

# %%
#get 68.952 rows

home_sample_df = home_df.sample(frac=0.01)

# %%
home_sample_df.to_csv ("home_sample0.01.csv", index = False)

# %%
home_sample_df = home_df.sample(frac=0.05)

# %%
home_sample_df.to_csv ("home_sample0.05.csv", index = False)
